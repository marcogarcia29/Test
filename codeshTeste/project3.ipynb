# %%
import pandas as pd 

math_student = pd.read_csv("./data/student-mat.csv", sep=";")
por_student = pd.read_csv("./data/student-por.csv", sep=";")

# %%
merged = math_student.merge(por_student, how='outer')
merged
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# # Quantidade de alunos da escola GP

# %%
school_gp = merged.loc[
    (merged.school == 'GP')
]
school_gp
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 813     GP   M   18       R     GT3       T     2     3     other  services
# 814     GP   M   19       U     GT3       T     2     1     other     other
# 815     GP   F   18       U     LE3       A     2     2  services     other
# 816     GP   F   20       U     GT3       T     1     0     other     other
# 817     GP   F   18       U     GT3       T     3     2  services     other
#
# ...

# %% [markdown]
# # Quantidade de alunos da escola GP que receberam ajuda extra-curricular

# %%
school_gp_helped = merged.loc[
    (merged.school == 'GP') &
    (merged.schoolsup == 'yes')
]
school_gp_helped
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 17      GP   F   16       U     GT3       T     3     3     other     other
# 24      GP   F   15       R     GT3       T     2     4  services    health
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 717     GP   F   19       R     GT3       T     3     2  services  services
# 723     GP   F   18       U     GT3       T     1     1     other     other
# 748     GP   F   18       U     GT3       T     1     4     other   teacher
# 761     GP   F   17       U     LE3       A     3     3  services     other
# 816     GP   F   20       U     GT3       T     1     0     other     other
#
# ...

# %% [markdown]
# # % de Alunos do colegio GP com ajuda extra-curricular

# %%
percentage = school_gp_helped['school'].count() / school_gp['school'].count()
percentage
# Out:
# 0.13860103626943004

# %% [markdown]
# # Quantidade de alunos da escola MS

# %%
school_ms = merged.loc[
    (merged.school == 'MS')
]
school_ms
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 349      MS   M   18       R     GT3       T     3     2     other     other
# 350      MS   M   19       R     GT3       T     1     1     other  services
# 351      MS   M   17       U     GT3       T     3     3    health     other
# 352      MS   M   18       U     LE3       T     1     3   at_home  services
# 353      MS   M   19       R     GT3       T     1     1     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# # Quantidade de alunos que receberam ajuda extra-curricular escola MS

# %%
school_ms_helped = merged.loc[
    (merged.school == 'GP') &
    (merged.schoolsup == 'yes')
]
school_ms_helped
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 17      GP   F   16       U     GT3       T     3     3     other     other
# 24      GP   F   15       R     GT3       T     2     4  services    health
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 717     GP   F   19       R     GT3       T     3     2  services  services
# 723     GP   F   18       U     GT3       T     1     1     other     other
# 748     GP   F   18       U     GT3       T     1     4     other   teacher
# 761     GP   F   17       U     LE3       A     3     3  services     other
# 816     GP   F   20       U     GT3       T     1     0     other     other
#
# ...

# %% [markdown]
# #  % de alunos do colégio MS que receberam ajuda extra-curricular

# %%
percentage1 = school_ms_helped['school'].count() / school_ms['school'].count()
percentage1
# Out:
# 0.39338235294117646
